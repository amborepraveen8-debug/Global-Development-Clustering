# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # EDA

# %%
# To display all columns
pd.set_option('display.max_columns', None)

# %%
# Load the data
data = pd.read_excel("data/World_development_mesurement.xlsx")

# %%
# get few data 
data.head()
# Out:
#    Birth Rate Business Tax Rate  CO2 Emissions       Country  \
# 0       0.020               NaN        87931.0       Algeria
# 1       0.050               NaN         9542.0        Angola
# 2       0.043               NaN         1617.0         Benin
# 3       0.027               NaN         4276.0      Botswana
# 4       0.046               NaN         1041.0  Burkina Faso
#
#    Days to Start Business  Ease of Business  Energy Usage              GDP  \
# 0                     NaN               NaN       26998.0  $54,790,058,957
# 1                     NaN               NaN        7499.0   $9,129,594,819
# 2                     NaN               NaN        1983.0   $2,359,122,303
# 3                     NaN               NaN        1836.0   $5,788,311,645
# 4                     NaN               NaN           NaN   $2,610,959,139
#
#    Health Exp % GDP Health Exp/Capita  Hours to do Tax  Infant Mortality Rate  \
# 0             0.035               $60              NaN                  0.034
# 1             0.034               $22              NaN                  0.128
# 2             0.043               $15              NaN                  0.090
# 3             0.047              $152              NaN                  0.054
# 4             0.051               $12              NaN                  0.096
#
#    Internet Usage  Lending Interest  Life Expectancy Female  \
# 0             0.0             0.100                    71.0
# 1             0.0             1.032                    47.0
# 2             0.0               NaN                    57.0
# 3             0.0             0.155                    52.0
# 4             0.0               NaN                    52.0
#
#    Life Expectancy Male  Mobile Phone Usage  Number of Records  \
# 0                  67.0                 0.0                  1
# 1                  44.0                 0.0                  1
# 2                  53.0                 0.0                  1
# 3                  49.0                 0.1                  1
# 4                  49.0                 0.0                  1
#
#    Population 0-14  Population 15-64  Population 65+  Population Total  \
# 0            0.342             0.619           0.039          31719449
# 1            0.476             0.499           0.025          13924930
# 2            0.454             0.517           0.029           6949366
# 3            0.383             0.587           0.029           1755375
# 4            0.468             0.505           0.028          11607944
#
#    Population Urban Tourism Inbound Tourism Outbound
# 0             0.599    $102,000,000     $193,000,000
# 1             0.324     $34,000,000     $146,000,000
# 2             0.383     $77,000,000      $50,000,000
# 3             0.532    $227,000,000     $209,000,000
# 4             0.178     $23,000,000      $30,000,000

# %%
# checking nuber of columns and rows in data set
data.shape
# Out:
# (2704, 25)

# %%
# getting information about data like datatpyes and null values 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Birth Rate              2585 non-null   float64
#  1   Business Tax Rate       1423 non-null   object
#  2   CO2 Emissions           2125 non-null   float64
#  3   Country                 2704 non-null   object
#  4   Days to Start Business  1718 non-null   float64
#  5   Ease of Business        185 non-null    float64
#  6   Energy Usage            1785 non-null   float64
#  7   GDP                     2494 non-null   object
#  8   Health Exp % GDP        2395 non-null   float64
#  9   Health Exp/Capita       2395 non-null   object
#  10  Hours to do Tax         1416 non-null   float64
#  11  Infant Mortality Rate   2444 non-null   float64
#  12  Internet Usage          2531 non-null   float64
#  13  Lending Interest        1880 non-null   float64
#  14  Life Expectancy Female  2568 non-null   float64
#  15  Life Expectancy Male    2568 non-null   float64
#  16  Mobile Phone Usage      2537 non-null   float64
#  17  Number of Records       2704 non-null   int64
#  18  Population 0-14         2484 non-null   float64
#  19  Population 15-64        2484 non-null   float64
#  20  Population 65+          2484 non-null   float64
#  21  Population Total        2704 non-null   int64
#  22  Population Urban        2678 non-null   float64
#  23  Tourism Inbound         2336 non-null   object
#  24  Tourism Outbound        2233 non-null   object
# dtypes: float64(17), int64(2), object(6)
# memory usage: 528.3+ KB

# %% [markdown]
# Columns contain currency symobls($, comma), convert to numeric
#
# column Business Tax Rate is having %

# %%
# Columns contain currency symobls($, comma), convert them to numeric
currency_cols = ['GDP', 'Health Exp/Capita','Tourism Inbound', 'Tourism Outbound']

for col in currency_cols:
    data[col] = (data[col].astype(str).str.replace('$', '', regex=False).str.replace(',', '', regex=False).astype(float))

# %%
# column Business Tax Rate is having %
data['Business Tax Rate']=data['Business Tax Rate'].astype(str).str.replace('%', '', regex=False).astype(float)

# %%
# think that the countary name is not useful for our clustring so droping the column, keeing it for interpretation
countries = data['Country']
data.drop(columns=['Country'], inplace=True)

# %%
# finding null values
data.isnull().sum()
# Out:
# Birth Rate                 119
# Business Tax Rate         1281
# CO2 Emissions              579
# Days to Start Business     986
# Ease of Business          2519
# Energy Usage               919
# GDP                        210
# Health Exp % GDP           309
# Health Exp/Capita          309
# Hours to do Tax           1288
# Infant Mortality Rate      260
# Internet Usage             173
# Lending Interest           824
# Life Expectancy Female     136
# Life Expectancy Male       136
# Mobile Phone Usage         167
# Number of Records            0
# Population 0-14            220
# Population 15-64           220
# Population 65+             220
# Population Total             0
# Population Urban            26
# Tourism Inbound            368
# Tourism Outbound           471
# dtype: int64

# %%
# columns having more missing values so to finding percentage of missing values
data.isnull().mean() *100
# Out:
# Birth Rate                 4.400888
# Business Tax Rate         47.374260
# CO2 Emissions             21.412722
# Days to Start Business    36.464497
# Ease of Business          93.158284
# Energy Usage              33.986686
# GDP                        7.766272
# Health Exp % GDP          11.427515
# Health Exp/Capita         11.427515
# Hours to do Tax           47.633136
# Infant Mortality Rate      9.615385
# Internet Usage             6.397929
# Lending Interest          30.473373
# Life Expectancy Female     5.029586
# Life Expectancy Male       5.029586
# Mobile Phone Usage         6.176036
# Number of Records          0.000000
# Population 0-14            8.136095
# Population 15-64           8.136095
# Population 65+             8.136095
# Population Total           0.000000
# Population Urban           0.961538
# Tourism Inbound           13.609467
# Tourism Outbound          17.418639
# dtype: float64

# %% [markdown]
# Here some features missing lots of data about more than 50% and near to it, so best to drop those columns.
#
# Those are 'Business Tax Rate' - 47%, 'Ease of Business' - 93%, 'Hours to do Tax ' - 47%

# %%
# removing the coloumns based on the ratio of the missing values, with 45% missing ratio 
missing_value_ratio = data.isnull().mean()
data = data.loc[:, missing_value_ratio < 0.45]

# %%
# filling null values with meadin, because it's robust to outliers
data.fillna(data.median(numeric_only=True), inplace=True)

# %%
# finding n unique values in each column
data.nunique()
# Out:
# Birth Rate                  47
# CO2 Emissions             1743
# Days to Start Business     126
# Energy Usage              1721
# GDP                       2495
# Health Exp % GDP           145
# Health Exp/Capita         1069
# Infant Mortality Rate      129
# Internet Usage              11
# Lending Interest           351
# Life Expectancy Female      49
# Life Expectancy Male        47
# Mobile Phone Usage          26
# Number of Records            1
# Population 0-14            377
# Population 15-64           299
# Population 65+             208
# Population Total          2699
# Population Urban           822
# Tourism Inbound           1651
# Tourism Outbound          1457
# dtype: int64

# %%
# removing the 'Number of Records' column because it's having constant value across the all the rows, such no-variance feature will not usefull
data.drop(columns=['Number of Records'], inplace=True)

# %%
# checking the dupicateed rows
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# finding the mean standard deviation, qunltiles and min max of the dta
data.describe()
# Out:
#         Birth Rate  CO2 Emissions  Days to Start Business  Energy Usage  \
# count  2704.000000   2.704000e+03             2704.000000  2.704000e+03
# mean      0.022595   1.136616e+05               34.894601  5.585961e+04
# std       0.011100   5.487421e+05               46.177780  2.132565e+05
# min       0.007000   7.000000e+00                1.000000  8.000000e+00
# 25%       0.013000   2.237000e+03               20.000000  7.851750e+03
# 50%       0.020000   8.529000e+03               26.000000  1.433800e+04
# 75%       0.030000   4.256200e+04               34.250000  2.347650e+04
# max       0.053000   8.286892e+06              694.000000  2.727728e+06
#
#                 GDP  Health Exp % GDP  Health Exp/Capita  \
# count  2.704000e+03       2704.000000        2704.000000
# mean   2.445336e+11          0.063807         731.872411
# std    1.087172e+12          0.024795        1400.121122
# min    6.310127e+07          0.008000           2.000000
# 25%    4.113748e+09          0.048000          58.000000
# 50%    1.507975e+10          0.061000         193.000000
# 75%    9.101825e+10          0.076000         551.250000
# max    1.624460e+13          0.225000        9908.000000
#
#        Infant Mortality Rate  Internet Usage  Lending Interest  \
# count            2704.000000     2704.000000       2704.000000
# mean                0.031581        0.230806          0.139539
# std                 0.028739        0.253983          0.143847
# min                 0.002000        0.000000          0.005000
# 25%                 0.010000        0.000000          0.097750
# 50%                 0.020000        0.100000          0.120000
# 75%                 0.049000        0.400000          0.149250
# max                 0.141000        1.000000          4.965000
#
#        Life Expectancy Female  Life Expectancy Male  Mobile Phone Usage  \
# count             2704.000000           2704.000000         2704.000000
# mean                71.352441             66.589497            0.573299
# std                 10.469114              9.167741            0.460136
# min                 39.000000             37.000000            0.000000
# 25%                 65.000000             61.000000            0.200000
# 50%                 75.000000             69.000000            0.500000
# 75%                 79.000000             73.000000            0.900000
# max                 87.000000             88.000000            2.900000
#
#        Population 0-14  Population 15-64  Population 65+  Population Total  \
# count      2704.000000       2704.000000     2704.000000      2.704000e+03
# mean          0.302762          0.625029        0.071718      3.145729e+07
# std           0.102152          0.066967        0.047844      1.242894e+08
# min           0.118000          0.474000        0.003000      1.887600e+04
# 25%           0.210000          0.565000        0.034000      8.783360e+05
# 50%           0.299500          0.642500        0.052000      5.800324e+06
# 75%           0.395000          0.673000        0.105000      2.014089e+07
# max           0.500000          0.858000        0.244000      1.350695e+09
#
#        Population Urban  Tourism Inbound  Tourism Outbound
# count       2704.000000     2.704000e+03      2.704000e+03
# mean           0.562924     4.360806e+09      3.985061e+09
# std            0.244712     1.295591e+10      1.216499e+10
# min            0.082000     7.000000e+05      2.000000e+05
# 25%            0.357750     1.860000e+08      1.470000e+08
# 50%            0.560000     6.885000e+08      4.560000e+08
# 75%            0.763000     2.648000e+09      1.711500e+09
# max            1.000000     2.000920e+11      1.265730e+11

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# checking correlation between the features
plt.figure(figsize=(13,8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
# finding data distribution and Skewnesss
data.hist(figsize=(15,12), bins=30)
plt.tight_layout()
plt.show()

# %%
# finding outliers using boxplot
num_cols = data.select_dtypes(include=['int64', 'float64']).columns

for col in num_cols:
    plt.figure(figsize=(5,3))
    sns.boxplot(x=data[col])
    plt.title(col)
    plt.show()

# %%
# handling outliers using isolation forest + capping(winsorization)
# because Outliers are multivariate (GDP + CO₂ + Health exp together)
# Using Isolation Forest to detect outliers.
# Using Winsorization to treat them, don't want to loss data.

from sklearn.ensemble import IsolationForest
from scipy.stats.mstats import winsorize

# %%
# detecting outliers
iso = IsolationForest(contamination=0.05, random_state=42)
labels = iso.fit_predict(data)

# capping values insted removing
df_treated = data.copy()

for col in data.columns:
    lower = data[col].quantile(0.05)
    upper = data[col].quantile(0.95)
    df_treated[col] = np.clip(data[col], lower, upper)

# %%
from sklearn.preprocessing import RobustScaler

# %%
# Since the data is skewed and contains extreme economic values in gdp, population etc, 
# used RobustScaler which is based on median and IQR instead of mean and standard deviation.
scaler = RobustScaler()
scaled_data = scaler.fit_transform(df_treated)
# After scaling, the data becomes a NumPy array and loses column names. So converting it back to a DataFrame to retain feature names.
scaled_df = pd.DataFrame(scaled_data, columns=data.columns)
scaled_df

# %%
scaled_df.to_csv("data/eda_preprocessed_data.csv", index=False)
